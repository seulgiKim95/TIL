# %%
import numpy as np
import pandas as pd

# %%
crime_anal_norm = pd.read_csv('../output/02. crime_in_Seoul_final.csv', sep=',', encoding='utf-8', index_col=0)
crime_anal_raw = pd.read_csv('../output/02. crime_location.csv', encoding='utf-8', index_col=0)
tmp_max = crime_anal_norm['검거'].max()
crime_anal_norm['검거']  = crime_anal_norm['검거']/tmp_max * 100
tmp_max = crime_anal_norm['범죄'].max()
crime_anal_norm['범죄']  = crime_anal_norm['범죄']/tmp_max * 100
crime_anal_norm.head()
crime_anal_raw.head()
#crime_anal_norm.info()
# Out:
#     관서명  살인 발생  살인 검거  강도 발생  강도 검거  강간 발생  강간 검거  절도 발생  절도 검거  폭력 발생  폭력 검거  \
# 0   중부서      2      2      3      2    105     65   1395    477   1355   1170
# 1   종로서      3      3      6      5    115     98   1070    413   1278   1070
# 2  남대문서      1      0      6      4     65     46   1153    382    869    794
# 3  서대문서      2      2      5      4    154    124   1812    738   2056   1711
# 4   혜화서      3      2      5      4     96     63   1114    424   1015    861
#
#      구별        lat         lng        검거
# 0    중구  37.563617  126.989652  1.275416
# 1   종로구  37.575548  126.984747  1.523847
# 2    중구  37.554758  126.973498  0.907372
# 3  서대문구  37.564744  126.966771  1.978299
# 4   종로구  37.571968  126.998957  1.198382

# %%
# %matplotlib inline
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib import font_manager, rc
plt.rcParams['axes.unicode_minus'] = False
f_path='C:/Windows/Fonts/malgun.ttf'
font_name = font_manager.FontProperties(fname=f_path).get_name()
rc('font', family=font_name)

# %%
import folium
import json
geo_path = '../data/02. skorea_municipalities_geo_simple.json'
geo_str = json.load(open(geo_path, encoding='utf-8'))
# geo_str

# %%
col = ['살인 검거', '강도 검거', '강간 검거', '절도 검거', '폭력 검거']

# %%
map = folium.Map(location=[37.5502, 126.982], zoom_start=11, width=1000, height=1000)
for n in crime_anal_raw.index:
    folium.CircleMarker([crime_anal_raw['lat'][n], crime_anal_raw['lng'][n]],\
                        radius=crime_anal_raw['검거'][n]*10, color='#3186cc', \
                        fill_color='#3186cc',fill=True).add_to(map)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_300344f147198fdeec6f67f625805785 {
#                     position: relative;
#                     width: 1000.0px;
#                     height: 1000.0px;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_300344f147198fdeec6f67f625805785&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_300344f147198fdeec6f67f625805785 = L.map(
#                 &quot;map_300344f147198fdeec6f67f625805785&quot;,
#                 {
#                     center: [37.5502, 126.982],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f3ace9f1843313c414345c50458abe6c = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_300344f147198fdeec6f67f625805785);
#
#
#             var circle_marker_80a93e8aaac47f4a617b086ad0164fb3 = L.circleMarker(
#                 [37.56361709999999, 126.9896517],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3186cc&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3186cc&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 12.754161313990176, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_300344f147198fdeec6f67f625805785);
#
#
#             var circle_marker_0a7a4921a6aaa077b5b506caf3dab54e = L.circleMarker(
#                 [37.575548, 126.98474709999999],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3186cc&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3186cc&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 15.238474819820112, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_300344f147198fdeec6f67f625805785);
#
#
#             var circle_marker_a8af971cedca6f29b6db782519a4dd9e = L.circleMarker(
#                 [37.5547584, 126.97349809999999],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3186cc&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3186cc&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 9.073722288993592, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_300344f147198fdeec6f67f625805785);
#
#
#             var circle_marker_cc85d660ac90cefce37b3236fbc67e8c = L.circleMarker(
#                 [37.5647439, 126.96677050000001],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3186cc&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3186cc&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 19.782994274892015, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_300344f147198fdeec6f67f625805785);
#
#
#             var circle_marker_b7cccd38c267a169f7a390cad4620c89 = L.circleMarker(
#                 [37.5719679, 126.99895740000001],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3186cc&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3186cc&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 11.983818821745583, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_300344f147198fdeec6f67f625805785);
#
#
#             var circle_marker_c1e1a578fc336dbd941fcc776b0303c9 = L.circleMarker(
#                 [37.5387099, 126.9659183],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3186cc&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3186cc&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 26.906854239104728, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_300344f147198fdeec6f67f625805785);
#
#
#             var circle_marker_f519fc997185099e11f5f96a2

# %%
map = folium.Map(location=[37.5502, 126.982], zoom_start=11, width=1000, height=1000)#, tiles='Stamen Toner')

map.choropleth(geo_data = geo_str, \
               data = crime_anal_norm['범죄'], \
               columns = [crime_anal_norm.index, crime_anal_norm['범죄']], \
               fill_color='BrBG', \
               key_on='feature.id') # geo_data 안의 feature.id 사용

for n in crime_anal_raw.index:
    folium.CircleMarker([crime_anal_raw['lat'][n], crime_anal_raw['lng'][n]],\
                        radius=crime_anal_raw['검거'][n]*10, color='#3186cc', \
                        fill_color='#3186cc',fill=True).add_to(map)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a31bc7dcebd526b13aa75d5101738c64 {
#                     position: relative;
#                     width: 1000.0px;
#                     height: 1000.0px;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a31bc7dcebd526b13aa75d5101738c64&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_a31bc7dcebd526b13aa75d5101738c64 = L.map(
#                 &quot;map_a31bc7dcebd526b13aa75d5101738c64&quot;,
#                 {
#                     center: [37.5502, 126.982],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_825acb0696d23287cdc016b6e5a2204b = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_a31bc7dcebd526b13aa75d5101738c64);
#
#
#             var choropleth_cd021022d48a156bc951525605b69688 = L.featureGroup(
#                 {}
#             ).addTo(map_a31bc7dcebd526b13aa75d5101738c64);
#
#
#         function geo_json_1fbdbb99e97f2dfaefd0c6bf5fbde539_styler(feature) {
#             switch(feature.id) {
#                 case &quot;\uc1a1\ud30c\uad6c&quot;: case &quot;\uad00\uc545\uad6c&quot;: case &quot;\uad6c\ub85c\uad6c&quot;: case &quot;\ub9c8\ud3ec\uad6c&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#c7eae5&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 case &quot;\uac15\ub0a8\uad6c&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#01665e&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 case &quot;\uc11c\ucd08\uad6c&quot;: case &quot;\uac15\uc11c\uad6c&quot;: case &quot;\ub178\uc6d0\uad6c&quot;: case &quot;\uc911\ub791\uad6c&quot;: case &quot;\uad11\uc9c4\uad6c&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#f6e8c3&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 case &quot;\uc601\ub4f1\ud3ec\uad6c&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#5ab4ac&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 case &quot;\uae08\ucc9c\uad6c&quot;: case &quot;\uc591\ucc9c\uad6c&quot;: case &quot;\uc11c\ub300\ubb38\uad6c&quot;: case &quot;\ub3c4\ubd09\uad6c&quot;: case &quot;\uc131\ubd81\uad6c&quot;: case &quot;\uc131\ub3d9\uad6c&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#8c510a&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 default:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#d8b365&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#             }
#         }
#
#         function geo_json_1fbdbb99e97f2dfaefd0c6bf5fbde539_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_1fbdbb99e97f2dfaefd0c6bf5fbde539 = L.geoJson(null, {
#                 onEachFeature: geo_json_1fbdbb99e97f2dfaefd0c6bf5fbde539_onEachFeature,
#
#                 style: geo_json_1fbdbb99e97f2dfaefd0c6bf5fbde539_styler,
#         });
#
#         function geo_json_1fbdbb99e97f2dfaefd0c6bf5fbde539_add (data) {
#             geo_json_1fbdbb99e97f2dfaefd0c6bf5fbde539
#                 .addData(data)
#                 .addTo(choropleth_cd021022d48a156bc951525605b69688);
#         }
#             geo_json_1fbdbb99e97f2dfaefd0c6bf5fbde539_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[127.11519584981606, 37.557533180704915], [127.16683184366129, 37.57672487388627], [127.18408792330152, 37.55814280369575], [127.16530984307447, 37.54221851258693], [127.14672806823502, 37.51415680680291], [127.12123165719615, 37.52528270089], [127.1116764203608, 37.540669955324965], [127.11519584981606, 37.557533180704915]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;\uac15\ub3d9\uad6c&quot;, &quot;properties&quot;: {&quot;base_year&quot;: &quot;2013&quot;, &quot;code&quot;: &quot;11250&quot;, &quot;name&quot;: &quot;\uac15\ub3d9\uad6c&quot;, &quot;name_eng&quot;: &quot;Gangdong-gu&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;geometry&quot;: {&quot;coordinates&quot;: [[[127.0690698130372, 37.522279423505026], [127.10087519791962, 37.524841220167055], [127.1116764203608, 37.540669955324965], [127.12123165719615, 37.52528270089], [127.14672806823502, 37.51415680680291], [127.1634944215765, 37.497445406097484], [127.14206058413274, 37.47089819098501], [127.12440571080893, 37.46240445587048], [127.11117085201238, 37.485708381512445], [127.0719146000724, 37.50224013587669], [127.0690698130372, 37.522279423505026]]],

# %%
from folium.plugins import MarkerCluster
map = folium.Map(location=[37.5502, 126.982], zoom_start=12, tiles='Stamen Toner', height=1000, width=1000)

map.choropleth(geo_data = geo_str, \
               data = crime_anal_norm['살인'], \
               columns = [crime_anal_norm.index, crime_anal_norm['살인']], \
               fill_color='BrBG', \
               key_on='feature.id') # geo_data 안의 feature.id 사용

marker_cluster = MarkerCluster().add_to(map)

for n in crime_anal_raw.index:
    folium.CircleMarker([crime_anal_raw['lat'][n], crime_anal_raw['lng'][n]],\
                        radius=crime_anal_raw['검거'][n]*10, color='#3186cc', \
                        fill_color='#3186cc',fill=True).add_to(map)
    #folium.Marker([crime_anal_raw['lat'][n], crime_anal_raw['lng'][n]], popup=crime_anal_raw['관서명'][n]).add_to(map)
    folium.Marker([crime_anal_raw['lat'][n], crime_anal_raw['lng'][n]], popup=crime_anal_raw['관서명'][n]).add_to(marker_cluster)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c68d85dee51eb94cbae92ea75f4da009 {
#                     position: relative;
#                     width: 1000.0px;
#                     height: 1000.0px;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c68d85dee51eb94cbae92ea75f4da009&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_c68d85dee51eb94cbae92ea75f4da009 = L.map(
#                 &quot;map_c68d85dee51eb94cbae92ea75f4da009&quot;,
#                 {
#                     center: [37.5502, 126.982],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_9ce860008a5f4bf71d732ba8e2c24356 = L.tileLayer(
#                 &quot;https://stamen-tiles-{s}.a.ssl.fastly.net/toner/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Map tiles by \u003ca href=\&quot;http://stamen.com\&quot;\u003eStamen Design\u003c/a\u003e, under \u003ca href=\&quot;http://creativecommons.org/licenses/by/3.0\&quot;\u003eCC BY 3.0\u003c/a\u003e. Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_c68d85dee51eb94cbae92ea75f4da009);
#
#
#             var choropleth_1c1fb7583c3a7e3a1c7f53bb7e19bcea = L.featureGroup(
#                 {}
#             ).addTo(map_c68d85dee51eb94cbae92ea75f4da009);
#
#
#         function geo_json_c6cb6dab1c7d08f4757dfc7226b23536_styler(feature) {
#             switch(feature.id) {
#                 case &quot;\uc1a1\ud30c\uad6c&quot;: case &quot;\ub178\uc6d0\uad6c&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#5ab4ac&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 case &quot;\uac15\ub0a8\uad6c&quot;: case &quot;\uc601\ub4f1\ud3ec\uad6c&quot;: case &quot;\uc911\ub791\uad6c&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#01665e&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 case &quot;\uc11c\ucd08\uad6c&quot;: case &quot;\uad00\uc545\uad6c&quot;: case &quot;\uad6c\ub85c\uad6c&quot;: case &quot;\ub9c8\ud3ec\uad6c&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#c7eae5&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 case &quot;\uae08\ucc9c\uad6c&quot;: case &quot;\uc591\ucc9c\uad6c&quot;: case &quot;\uc11c\ub300\ubb38\uad6c&quot;: case &quot;\uc740\ud3c9\uad6c&quot;: case &quot;\ub3c4\ubd09\uad6c&quot;: case &quot;\uc911\uad6c&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#8c510a&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 case &quot;\uac15\uc11c\uad6c&quot;: case &quot;\uac15\ubd81\uad6c&quot;: case &quot;\uc885\ub85c\uad6c&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#f6e8c3&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 default:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#d8b365&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#             }
#         }
#
#         function geo_json_c6cb6dab1c7d08f4757dfc7226b23536_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_c6cb6dab1c7d08f4757dfc7226b23536 = L.geoJson(null, {
#                 onEachFeature: geo_json_c6cb6dab1c7d08f4757dfc7226b23536_onEachFeature,
#
#                 style: geo_json_c6cb6dab1c7d08f4757dfc7226b23536_styler,
#         });
#
#         function geo_json_c6cb6dab1c7d08f4757dfc7226b23536_add (data) {
#             geo_json_c6cb6dab1c7d08f4757dfc7226b23536
#                 .addData(data)
#                 .addTo(choropleth_1c1fb7583c3a7e3a1c7f53bb7e19bcea);
#         }
#             geo_json_c6cb6dab1c7d08f4757dfc7226b23536_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[127.11519584981606, 37.557533180704915], [127.16683184366129, 37.57672487388627], [127.18408792330152, 37.55814280369575], [127.16530984307447, 37.54221851258693], [127.14672806823502, 37.51415680680291], [127.12123165719615, 37.52528270089], [127.1116764203608, 37.540669955324965], [127.11519584981606, 37.557533180704915]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;\uac15\ub3d9\uad6c&quot;, &quot;properties&quot;: {&quot;base_year&quot;: &quot;20

# %%
map = folium.Map(location=[37.5502, 126.982], zoom_start=12)#
for n in crime_anal_raw.index:
    string = f'경찰서 이름 : {crime_anal_raw["관서명"][n]} </br> 폭력 발생 수 :{crime_anal_raw["폭력 발생"][n]}'
    icon_url = '../data/police.png'
    icon = folium.features.CustomIcon(icon_url, icon_size=(45, 45))
    popup = folium.Popup(string, min_width=130, max_width=130)
    folium.Marker([crime_anal_raw['lat'][n], crime_anal_raw['lng'][n]], popup=popup, icon=icon).add_to(map)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5c20d1af8ef052a7ba73b946fe51bf0f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5c20d1af8ef052a7ba73b946fe51bf0f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_5c20d1af8ef052a7ba73b946fe51bf0f = L.map(
#                 &quot;map_5c20d1af8ef052a7ba73b946fe51bf0f&quot;,
#                 {
#                     center: [37.5502, 126.982],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ff4c42e4922a530f20026fff64b25055 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_5c20d1af8ef052a7ba73b946fe51bf0f);
#
#
#             var marker_c1912f5a42205a085884141155755a7b = L.marker(
#                 [37.56361709999999, 126.9896517],
#                 {}
#             ).addTo(map_5c20d1af8ef052a7ba73b946fe51bf0f);
#
#
#         var custom_icon_2332d3a34cf9d32b5867932f73c67a24 = L.icon({&quot;iconSize&quot;: [45, 45], &quot;iconUrl&quot;: &quot;data:image/png;base64,...&quot;});
#         marker_c1912f5a42205a085884141155755a7b.setIcon(custom_icon_2332d3a34cf9d32b5867932f73c67a24);
#
#
#         var popup_1621d9166c26e2858f80ea51c6b1c667 = L.popup({&quot;maxWidth&quot;: 130, &quot;minWidth&quot;: 130});
#
#
#             var html_5b63dd5c4bffb6df9432bcb4a8b220d2 = $(`&lt;div id=&quot;html_5b63dd5c4bffb6df9432bcb4a8b220d2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;경찰서 이름 : 중부서 &lt;/br&gt; 폭력 발생 수 :1355&lt;/div&gt;`)[0];
#             popup_1621d9166c26e2858f80ea51c6b1c667.setContent(html_5b63dd5c4bffb6df9432bcb4a8b220d2);
#
#
#         marker_c1912f5a42205a085884141155755a7b.bindPopup(popup_1621d9166c26e2858f80ea51c6b1c667)
#         ;
#
#
#
#
#             var marker_03f777dfcdc0fe4176a9b20ca2d5d939 = L.marker(
#                 [37.575548, 126.98474709999999],
#                 {}
#             ).addTo(map_5c20d1af8ef052a7ba73b946fe51bf0f);
#
#
#         var custom_icon_a83a6c44b249768d360f6e758342f68c = L.icon({&quot;iconSize&quot;: [45, 45], &quot;iconUrl&quot;: &quot;data:image/png;base64,...&quot;});
#         marker_03f777dfcdc0fe4176a9b20ca2d5d939.setIcon(custom_icon_a83a6c44b249768d360f6e758342f68c);
#
#
#         var popup_74ea6b196f15663179e8e0c808187cca = L.popup({&quot;maxWidth&quot;: 130, &quot;minWidth&quot;: 130});
#
#
#             var html_b07581238fd76f71ac54108f79f856fb = $(`&lt;div id=&quot;html_b07581238fd76f71ac54108f79f856fb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;경찰서 이름 : 종로서 &lt;/br&gt; 폭력 발생 수 :1278&lt;/div&gt;`)[0];
#             popup_74ea6b196f15663179e8e0c808187cca.setContent(html_b07581238fd76f71ac54108f79f856fb);
#
#
#         marker_03f777dfcdc0fe4176a9b20ca2d5d939.bindPopup(popup_74ea6b196f15663179e8e0c808187cca)
#         ;
#
#
#
#
#             var marker_021d49e2b86eee48a9f329fac00a9c2d = L.marker(
#                 [37.5547584, 126.97349809999999],
#                 {}
#             ).addTo(map_5c20d1af8ef052a7ba73b946fe51bf0f);
#
#
#         var custom_icon_92f07b90e33254234211588e9a76555b = L.icon({&quot;iconSize&quot;: [45, 45], &quot;iconUrl&quot;: &quot;data:image/png;base64,...&quot;});
#         marker_021d49e2b86eee48a9f329fac00a9c2d.setIcon(custom_icon_92f07b90e33254234211588e9a76555b);
#
#
#         var popup_bd41d86b1d84c5973fd91a2c196f0a6a = L.popup({&quot;maxWidth&quot;: 130, &quot;minWidth&quot;: 130});
#
#
#             var html_f4bc96596c991b7f493259375083c2b2 = $(`&lt;div id=&quot;html_f4bc96596c991b7f493259375083c2b2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;경찰서 이름 : 남대문서 &lt;/br&gt; 폭력 발생 수 :869&lt;/div&gt;`)[0];
#             popup_bd41d86b1d84c5973fd91a2c196f0a6a.setContent(html_f4bc96596c991b7f493259375083c2b2);
#
#
#         marker_021d49e2b86eee48a9f329fac00a9c2d.bindPopup(popup_bd41d86b1d84c5973fd91a2c196f0a6a)
#         ;
#
#
#
#
#             var marker_b4ae099e62e2e86839989d2db1970c71 = L.marker(
#                 [37.5647439, 126.96677050000001],
#                 {}
#             ).addTo(map_5c20d1af8ef052a7ba73b946fe51bf0f);
#
#
#         var custom_icon_eee60ecef393bf6ba9aff36ad1c82bbf = L.icon({&quot;iconSize&quot;: [45, 45], &quot;iconUrl&quot;: &quot;data:image/png;base64,...&quot;});
#         marker_b4ae099e62e2e86839989d2db1970c71.setIcon(custom_icon_eee60ecef393bf6ba9aff36ad1c82bbf);
#
#
#         var popup_b0b6efdbed58ea7f0b88902a16f515c4 = L.popup({&quot;maxWidth&quot;: 130, &quot;minWidth&quot;: 130});
#
#
#             var html_abae53971c13d16ceb9ced43cb970971 = $(`&lt;div id=&quot;html_abae53971c13d16ceb9ced43cb970971&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;경찰서 이름 : 서대문서 &lt;/br&gt; 폭력 발생 수 :2056&lt;/div&gt;`)[0];
#             popup_b0b6efdbed58ea7f0b88902a16f515c4.setContent(html_abae53971c13d16ceb9ced43cb970971);
#
#
#         marker
